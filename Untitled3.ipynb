# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()

# ✅ This is correct
# !yolo checks
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.7/112.6 GB disk)
#
# OS                     Linux-6.6.97+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.11
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   39.7/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 15095MiB
# GPU count              1
# CUDA                   12.6
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.12.0.88>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.2>=1.4.1
# torch                  ✅ 2.8.0+cu126>=1.8.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0ENEraz3yWeq5xqRHIKm")
project = rf.workspace("telkom-university-mfinb").project("plant-village-dataset-nyrhs")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=80 imgsz=640 project='/content/drive/MyDrive/yolov8_output'
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/yolov8_output/train/weights/best.pt' conf=0.25 source='{dataset.location}/test/images' save=True
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:31]:
      display(Image(filename=image_path, height=600))
      print("\n")
