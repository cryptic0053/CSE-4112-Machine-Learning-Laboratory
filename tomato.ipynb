# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()

# ✅ This is correct
# !yolo checks
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.7/112.6 GB disk)
#
# OS                     Linux-6.6.97+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.11
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   39.7/112.6 GB
# CPU                    Intel Xeon CPU @ 2.00GHz
# CPU count              2
# GPU                    Tesla T4, 15095MiB
# GPU count              1
# CUDA                   12.6
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.12.0.88>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.2>=1.4.1
# torch                  ✅ 2.8.0+cu126>=1.8.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="I0IFcZubhHgHfSnW9Dm3")
project = rf.workspace("masked-pi").project("tomato-onfvb")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !ls -lah /content/tomato_rf || echo "tomato_rf folder missing"
# !find /content/tomato_rf -maxdepth 3 -print || true
# Out:
# total 12K
# drwxr-xr-x 2 root root 4.0K Oct  5 16:12 .
# drwxr-xr-x 1 root root 4.0K Oct  5 16:12 ..
# /content/tomato_rf

# %%
from google.colab import files
up = files.upload()  # Choose the file: tomato.v1.yolov8.zip
# Out:
#      <input type="file" id="files-9ae1dee5-6605-4a22-8812-5b733eb120dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ae1dee5-6605-4a22-8812-5b733eb120dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p /content/tomato_yolov8
# !unzip -q -o "tomato.v1i.yolov8.zip" -d /content/tomato_yolov8
# !find /content/tomato_yolov8 -maxdepth 3 -type f -name "data.yaml" -print
# Out:
# /content/tomato_yolov8/data.yaml

# %%
# (Optional) save outputs to Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !yolo task=detect mode=train model=yolov8m.pt \
    data="/content/tomato_yolov8/data.yaml" \
    epochs=80 imgsz=640 batch=16 \
    project="/content/drive/MyDrive/yolov8_output" name="train_tomato"
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict \
    model="/content/drive/MyDrive/yolov8_output/train_tomato/weights/best.pt" \
    source="/content/tomato_yolov8/test/images" \
    project="/content/drive/MyDrive/yolov8_output" name="pred_tomato"
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/31 /content/tomato_yolov8/test/images/HEALTHY_39_jpg.rf.ff15bca36306e95ab94f789372e7e303.jpg: 640x640 6 tomato_leavess, 37.0ms
# image 2/31 /content/tomato_yolov8/test/images/HEALTHY_3_jpg.rf.0fcd71816ce76561c6d65df5aa7527d9.jpg: 640x640 1 tomato_leaves, 36.9ms
# image 3/31 /content/tomato_yolov8/test/images/TBB_107_jpg.rf.2fd2ad0754739b463d5bee7b0432fbe3.jpg: 640x640 4 tomato_bacterial_blights, 37.0ms
# image 4/31 /content/tomato_yolov8/test/images/TBB_124_jpg.rf.7522e5a12f9edca87acaf2d1bac329f5.jpg: 640x640 2 tomato_bacterial_blights, 37.0ms
# image 5/31 /content/tomato_yolov8/test/images/TBB_132_jpg.rf.0b7def639751b0262b2045a3443b70b1.jpg: 640x640 2 tomato_bacterial_blights, 35.9ms
# ...
