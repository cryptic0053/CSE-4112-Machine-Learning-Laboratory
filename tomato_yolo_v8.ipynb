# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()

# ✅ This is correct
# !yolo checks
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/112.6 GB disk)
#
# OS                  Linux-6.1.123+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.13
# Install             pip
# Path                /usr/local/lib/python3.11/dist-packages/ultralytics
# RAM                 12.67 GB
# Disk                41.5/112.6 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           2
# GPU                 Tesla T4, 15095MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 2.0.2>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.11.0.86>=4.6.0
# pillow              ✅ 11.2.1>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.15.3>=1.4.1
# torch               ✅ 2.6.0+cu124>=1.8.0
# torch               ✅ 2.6.0+cu124!=2.4.0,>=1.8.0; sys_platform == "win32"
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="I0IFcZubhHgHfSnW9Dm3")
project = rf.workspace("masked-pi").project("tomato-onfvb")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tomato-1 in yolov8:: 100%|██████████| 1500/1500 [00:00<00:00, 5501.08it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=80 imgsz=640 project='/content/drive/MyDrive/yolov8_output'
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/yolov8_output/train/weights/best.pt' conf=0.25 source='{dataset.location}/test/images' save=True
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/31 /content/tomato-1/test/images/HEALTHY_39_jpg.rf.ff15bca36306e95ab94f789372e7e303.jpg: 640x640 4 tomato_leavess, 37.3ms
# image 2/31 /content/tomato-1/test/images/HEALTHY_3_jpg.rf.0fcd71816ce76561c6d65df5aa7527d9.jpg: 640x640 1 tomato_leaves, 38.1ms
# image 3/31 /content/tomato-1/test/images/TBB_107_jpg.rf.2fd2ad0754739b463d5bee7b0432fbe3.jpg: 640x640 8 tomato_bacterial_blights, 37.1ms
# image 4/31 /content/tomato-1/test/images/TBB_124_jpg.rf.7522e5a12f9edca87acaf2d1bac329f5.jpg: 640x640 3 tomato_bacterial_blights, 37.1ms
# image 5/31 /content/tomato-1/test/images/TBB_132_jpg.rf.0b7def639751b0262b2045a3443b70b1.jpg: 640x640 2 tomato_bacterial_blights, 37.1ms
# image 6/31 /content/tomato-1/test/images/TBB_138_jpg.rf.4dc2c9ea564acac26bc6dc85c8b6d10a.jpg: 640x640 2 tomato_bacterial_blights, 27.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:31]:
      display(Image(filename=image_path, height=600))
      print("\n")
